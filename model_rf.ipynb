# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (from scikit-learn->sklearn) (0.15.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (from scikit-learn->sklearn) (1.5.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\nickv\anaconda3\envs\pythonadvanced2\lib\site-packages (0.15.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.

# 'koi_period','koi_time0bk','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr',
# 'koi_tce_plnt_num','koi_steff','koi_slogg','koi_srad','ra','dec','koi_kepmag'

selected_features = df[['koi_period','koi_time0bk','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr','koi_tce_plnt_num','koi_steff','koi_slogg','koi_srad','ra','dec','koi_kepmag']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X = selected_features
y = df["koi_disposition"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print("Shape: ", X.shape, y.shape)
df.loc[df["koi_disposition"]=="CANDIDATE"]
# Out:
# Shape:  (6991, 16) (6991,)
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 29         CANDIDATE              0              0              0
# 47         CANDIDATE              0              0              0
# 50         CANDIDATE              0              0              0
# 51         CANDIDATE              0              0              0
# 59         CANDIDATE              0              0              0
# ...              ...            ...            ...            ...
# 6979       CANDIDATE              0              0              0
# 6980       CANDIDATE              0              0              0
# 6984       CANDIDATE              0              0              0
# 6985       CANDIDATE              0              0              0
# 6988       CANDIDATE              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 29                0    4.959319     5.150000e-07    -5.150000e-07
# 47                0   40.419504     1.139000e-04    -1.139000e-04
# 50                0    7.240661     1.620000e-05    -1.620000e-05
# 51                0    3.435916     4.730000e-05    -4.730000e-05
# 59                0    1.626630     1.020000e-06    -1.020000e-06
# ...             ...         ...              ...              ...
# 6979              0    4.736816     1.470000e-04    -1.470000e-04
# 6980              0  130.235324     3.030000e-03    -3.030000e-03
# 6984              0    8.870416     9.020000e-06    -9.020000e-06
# 6985              0   47.109631     1.940000e-04    -1.940000e-04
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 29     172.258529          0.000083  ...             -77      4.359
# 47     173.564690          0.002220  ...            -163      4.507
# 50     137.755450          0.002000  ...             -79      4.595
# 51     132.662400          0.011000  ...            -115      4.339
# 59     169.820171          0.000487  ...            -172      4.410
# ...           ...               ...  ...             ...        ...
# 6979   131.787600          0.025600  ...            -201      4.456
# 6980   218.271900          0.020100  ...            -183      4.529
# 6984   137.481093          0.000869  ...            -181      4.027
# 6985   144.131720          0.003430  ...            -159      3.597
# 6988   133.001270          0.007690  ...            -220      4.444
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 29             0.110          -0.110     1.082          0.173         -0.130
# 47             0.116          -0.105     0.781          0.116         -0.095
# 50             0.012          -0.064     0.765          0.055         -0.028
# 51             0.132          -0.108     1.087          0.157         -0.142
# 59             0.124          -0.186     0.973          0.270         -0.145
# ...              ...             ...       ...            ...            ...
# 6979           0.056          -0.224     1.011          0.329         -0.110
# 6980           0.036          -0.192     0.903          0.251         -0.084
# 6984           0.434          -0.186     1.514          0.426         -0.640
# 6985           0.968          -0.242     2.780          1.089         -2.022
# 6988           0.056          -0.224     1.031          0.341         -0.114
#
#              ra        dec  koi_kepmag
# 29    292.16705  48.727589      15.263
# 47    294.31686  50.080231      15.487
# 50    293.83331  50.230350      15.334
# 51    287.88733  46.276241      12.791
# 59    294.36819  38.310280      15.279
# ...         ...        ...         ...
# 6979  289.20331  44.505138      13.922
# 6980  289.57452  44.519939      15.991
# 6984  290.14914  50.239178      13.579
# 6985  296.15601  44.920090      13.731
# 6988  286.50937  47.163219      14.757
#
# [1687 rows x 41 columns]

# %%
X_train.head()
# Out:
#       koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 6122    6.768901   133.077240       0.150       3.61600      123.1      1.24
# 6370    0.733726   132.020050       0.291       2.30900      114.6      0.86
# 2879    7.652707   134.460380       0.970      79.89690      641.1      3.21
# 107     7.953547   174.662240       0.300       2.63120      875.4      2.25
# 29      4.959319   172.258529       0.831       2.22739     9802.0     12.21
#
#       koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  \
# 6122     1017     253.30           10.8                 1       5737
# 6370     1867    2891.64           13.8                 1       5855
# 2879      989     226.81          254.3                 1       6328
# 107       696      55.37           38.4                 1       4768
# 29       1103     349.40          696.5                 1       5712
#
#       koi_slogg  koi_srad         ra        dec  koi_kepmag
# 6122      4.327     1.125  294.40472  39.351681      14.725
# 6370      4.578     0.797  284.50391  42.463860      15.770
# 2879      4.481     0.963  295.50211  38.983540      13.099
# 107       4.536     0.779  291.15878  40.750271      15.660
# 29        4.359     1.082  292.16705  48.727589      15.263

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, encoded_y_train)

print(f"Training Data Score: {rf.score(X_train_scaled, encoded_y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, encoded_y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.755720823798627

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.svm import SVC 

from sklearn.model_selection import GridSearchCV
param_grid = { 
    'n_estimators': [200, 700]
}
grid2 = GridSearchCV(estimator=rf, param_grid=param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid2.fit(X_train_scaled, encoded_y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] n_estimators=200 ................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................... n_estimators=200, score=0.781, total=   2.5s
# [CV] n_estimators=200 ................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [CV] .................... n_estimators=200, score=0.771, total=   2.5s
# [CV] n_estimators=200 ................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.8s remaining:    0.0s
# [CV] .................... n_estimators=200, score=0.746, total=   2.5s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.769, total=   2.4s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.766, total=   2.5s
# [CV] n_estimators=700 ................................................
# [CV] .................... n_estimators=700, score=0.778, total=   8.9s
# [CV] n_estimators=700 ................................................
# [CV] .................... n_estimators=700, score=0.771, total=   8.9s
# [CV] n_estimators=700 ................................................
# [CV] .................... n_estimators=700, score=0.753, total=   9.1s
# [CV] n_estimators=700 ................................................
# [CV] .................... n_estimators=700, score=0.763, total=   8.9s
# [CV] n_estimators=700 ................................................
# [CV] .................... n_estimators=700, score=0.770, total=   9.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   57.0s finished
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=200),
#              param_grid={'n_estimators': [200, 700]}, verbose=3)

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'n_estimators': 700}
# 0.7671179021823765

# %%
predictions = grid2.predict(X_test_scaled)

from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions,
                            target_names=["Candidate", "Confirmed", "False Positive"]))
# Out:
#                 precision    recall  f1-score   support
#
#      Candidate       0.61      0.52      0.56       411
#      Confirmed       0.78      0.82      0.80       484
# False Positive       0.81      0.84      0.82       853
#
#       accuracy                           0.76      1748
#      macro avg       0.73      0.73      0.73      1748
#   weighted avg       0.75      0.76      0.75      1748

# %%
import joblib
filename = 'nv_rf.sav'
joblib.dump(rf, filename)
# Out:
# ['nv_rf.sav']
